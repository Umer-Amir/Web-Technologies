# %% [markdown]
# ### React Conceptual MCQs:
#
# 1. **What is React primarily used for?**
#    - A) Building server-side applications
#    - B) Building user interfaces
#    - C) Database management
#    - D) Network security
#
# 2. **Who developed React?**
#    - A) Google
#    - B) Facebook
#    - C) Microsoft
#    - D) Amazon
#
# 3. **What does the term "JSX" stand for?**
#    - A) JavaScript XML
#    - B) Java Syntax Extension
#    - C) JavaScript Execution
#    - D) Java Source XML
#
# 4. **In React, what is a "component"?**
#    - A) A reusable piece of UI
#    - B) A type of database entity
#    - C) A server-side function
#    - D) A CSS style rule
#
# 5. **What is the purpose of the `render()` method in a React component?**
#    - A) To initialize state
#    - B) To update the DOM
#    - C) To define the component's UI
#    - D) To handle events
#
# 6. **What is "state" in a React component?**
#    - A) A constant value
#    - B) A variable that determines the component's behavior and rendering
#    - C) A method to handle events
#    - D) A CSS class
#
# 7. **What does "props" stand for in React?**
#    - A) Properties
#    - B) Propositions
#    - C) Prototypes
#    - D) Promises
#
# 8. **How can you update the state in a React component?**
#    - A) Using the `updateState` method
#    - B) Directly modifying the state object
#    - C) Using the `setState` method
#    - D) Using the `render` method
#
# 9. **What is the virtual DOM in React?**
#    - A) A virtual representation of the actual DOM
#    - B) A server-side rendering technique
#    - C) A real-time data synchronization method
#    - D) A type of state management
#
# 10. **What lifecycle method is called after a component is rendered for the first time?**
#     - A) componentDidMount
#     - B) componentWillMount
#     - C) componentDidUpdate
#     - D) componentWillUpdate
#
# 11. **What does the `shouldComponentUpdate` lifecycle method do?**
#     - A) It controls whether a component should re-render
#     - B) It initializes state
#     - C) It handles events
#     - D) It updates the DOM
#
# 12. **What is a "pure component" in React?**
#     - A) A component that only accepts props
#     - B) A component that does not have a state
#     - C) A component that does not render any UI
#     - D) A component that implements `shouldComponentUpdate` with a shallow prop and state comparison
#
# 13. **What is the purpose of `React.Fragment`?**
#     - A) To create a reusable piece of UI
#     - B) To group multiple elements without adding extra nodes to the DOM
#     - C) To manage state
#     - D) To handle side effects
#
# 14. **How can you create a context in React?**
#     - A) Using the `createContext` function
#     - B) Using the `useContext` hook
#     - C) Both A and B
#     - D) Neither A nor B
#
# 15. **What is a "hook" in React?**
#     - A) A way to handle events
#     - B) A function that lets you use state and other React features in functional components
#     - C) A method for fetching data
#     - D) A CSS property
#
# 16. **Which hook is used to add state to a functional component?**
#     - A) useState
#     - B) useEffect
#     - C) useReducer
#     - D) useContext
#
# 17. **What is the purpose of the `useEffect` hook?**
#     - A) To add state to a functional component
#     - B) To manage side effects in functional components
#     - C) To create a context
#     - D) To handle events
#
# 18. **How can you pass data from a parent component to a child component in React?**
#     - A) Using state
#     - B) Using props
#     - C) Using context
#     - D) Using hooks
#
# 19. **What is the purpose of the `useRef` hook?**
#     - A) To manage state
#     - B) To manage side effects
#     - C) To persist values across renders without causing re-renders
#     - D) To create a context
#
# 20. **What does "SSR" stand for in the context of React?**
#     - A) Server-Side Rendering
#     - B) State Synchronization Routine
#     - C) Static Site Rendering
#     - D) Server-Side Request
#
# ### GraphQL Conceptual MCQs:
#
# 1. **What is GraphQL primarily used for?**
#    - A) Database management
#    - B) Querying APIs
#    - C) Styling web pages
#    - D) Server configuration
#
# 2. **Who developed GraphQL?**
#    - A) Google
#    - B) Facebook
#    - C) Microsoft
#    - D) Amazon
#
# 3. **What does GraphQL stand for?**
#    - A) Graph Query Language
#    - B) Graph Quality Language
#    - C) GraphQL does not stand for anything
#    - D) Graph Query Linter
#
# 4. **What is a "query" in GraphQL?**
#    - A) A request to read data from the server
#    - B) A request to update data on the server
#    - C) A request to delete data on the server
#    - D) A request to subscribe to data changes
#
# 5. **What is a "mutation" in GraphQL?**
#    - A) A request to read data from the server
#    - B) A request to update or modify data on the server
#    - C) A request to delete data on the server
#    - D) A request to subscribe to data changes
#
# 6. **What is a "subscription" in GraphQL?**
#    - A) A request to read data from the server
#    - B) A request to update or modify data on the server
#    - C) A request to delete data on the server
#    - D) A request to receive real-time updates when data changes
#
# 7. **What is a "schema" in GraphQL?**
#    - A) A type of database table
#    - B) A description of the data and its structure
#    - C) A type of query
#    - D) A type of mutation
#
# 8. **In GraphQL, what is a "resolver"?**
#    - A) A function that resolves a value for a type or field in a schema
#    - B) A method for managing API requests
#    - C) A tool for database queries
#    - D) A library for state management
#
# 9. **What does a GraphQL query return?**
#    - A) All available data from the server
#    - B) Only the specific data requested by the client
#    - C) Metadata about the API
#    - D) A fixed set of data predefined by the server
#
# 10. **Which of the following is true about GraphQL?**
#     - A) It is a replacement for REST APIs
#     - B) It allows clients to request exactly the data they need
#     - C) It only works with SQL databases
#     - D) It is a front-end framework
#
# 11. **What is the purpose of the `type` keyword in a GraphQL schema?**
#     - A) To define a query
#     - B) To define a mutation
#     - C) To define the structure of data
#     - D) To define a subscription
#
# 12. **What is the purpose of the `query` keyword in a GraphQL schema?**
#     - A) To define the structure of data
#     - B) To define the entry points for reading data
#     - C) To define the entry points for modifying data
#     - D) To define the entry points for subscribing to data changes
#
# 13. **What is the purpose of the `mutation` keyword in a GraphQL schema?**
#     - A) To define the structure of data
#     - B) To define the entry points for reading data
#     - C) To define the entry points for modifying data
#     - D) To define the entry points for subscribing to data changes
#
# 14. **What is the purpose of the `subscription` keyword in a GraphQL schema?**
#     - A) To define the structure of data
#     - B) To define the entry points for reading data
#     - C) To define the entry points for modifying data
#     - D) To define the entry points for subscribing to data changes
#
# 15. **In GraphQL, what is an "enum"?**
#     - A) A type of query
#     - B) A type of mutation
#     - C) A special type that represents a set of constant values
#     - D) A special type that represents a set of dynamic values
#
# 16. **What is the purpose of the `!` symbol in a GraphQL schema?**
#     - A) To indicate that a field is nullable
#     - B) To indicate that a field is non-nullable
#     - C) To define a query
#     - D) To define a mutation
#
# 17.
#
#  **What is the purpose of the `input` keyword in a GraphQL schema?**
#     - A) To define the structure of data
#     - B) To define the input types for mutations
#     - C) To define the input types for queries
#     - D) To define the input types for subscriptions
#
# 18. **What is the difference between `List` and `Non-Null` types in GraphQL?**
#     - A) List represents a collection of values, Non-Null indicates a value cannot be null
#     - B) List represents a single value, Non-Null indicates a collection of values
#     - C) List indicates a value cannot be null, Non-Null represents a collection of values
#     - D) List and Non-Null are the same in GraphQL
#
# 19. **Which of the following is NOT a valid GraphQL operation type?**
#     - A) Query
#     - B) Mutation
#     - C) Subscription
#     - D) Procedure
#
# 20. **What is the purpose of the `@` symbol in a GraphQL query?**
#     - A) To define a variable
#     - B) To define a directive
#     - C) To define a fragment
#     - D) To define a schema

# %% [markdown]
# ### React Conceptual MCQs with Answers:
#
# 1. **What is React primarily used for?**
#    - **Answer:** B) Building user interfaces
#
# 2. **Who developed React?**
#    - **Answer:** B) Facebook
#
# 3. **What does the term "JSX" stand for?**
#    - **Answer:** A) JavaScript XML
#
# 4. **In React, what is a "component"?**
#    - **Answer:** A) A reusable piece of UI
#
# 5. **What is the purpose of the `render()` method in a React component?**
#    - **Answer:** C) To define the component's UI
#
# 6. **What is "state" in a React component?**
#    - **Answer:** B) A variable that determines the component's behavior and rendering
#
# 7. **What does "props" stand for in React?**
#    - **Answer:** A) Properties
#
# 8. **How can you update the state in a React component?**
#    - **Answer:** C) Using the `setState` method
#
# 9. **What is the virtual DOM in React?**
#    - **Answer:** A) A virtual representation of the actual DOM
#
# 10. **What lifecycle method is called after a component is rendered for the first time?**
#     - **Answer:** A) componentDidMount
#
# 11. **What does the `shouldComponentUpdate` lifecycle method do?**
#     - **Answer:** A) It controls whether a component should re-render
#
# 12. **What is a "pure component" in React?**
#     - **Answer:** D) A component that implements `shouldComponentUpdate` with a shallow prop and state comparison
#
# 13. **What is the purpose of `React.Fragment`?**
#     - **Answer:** B) To group multiple elements without adding extra nodes to the DOM
#
# 14. **How can you create a context in React?**
#     - **Answer:** C) Both A and B
#
# 15. **What is a "hook" in React?**
#     - **Answer:** B) A function that lets you use state and other React features in functional components
#
# 16. **Which hook is used to add state to a functional component?**
#     - **Answer:** A) useState
#
# 17. **What is the purpose of the `useEffect` hook?**
#     - **Answer:** B) To manage side effects in functional components
#
# 18. **How can you pass data from a parent component to a child component in React?**
#     - **Answer:** B) Using props
#
# 19. **What is the purpose of the `useRef` hook?**
#     - **Answer:** C) To persist values across renders without causing re-renders
#
# 20. **What does "SSR" stand for in the context of React?**
#     - **Answer:** A) Server-Side Rendering
#
# ### GraphQL Conceptual MCQs with Answers:
#
# 1. **What is GraphQL primarily used for?**
#    - **Answer:** B) Querying APIs
#
# 2. **Who developed GraphQL?**
#    - **Answer:** B) Facebook
#
# 3. **What does GraphQL stand for?**
#    - **Answer:** C) GraphQL does not stand for anything
#
# 4. **What is a "query" in GraphQL?**
#    - **Answer:** A) A request to read data from the server
#
# 5. **What is a "mutation" in GraphQL?**
#    - **Answer:** B) A request to update or modify data on the server
#
# 6. **What is a "subscription" in GraphQL?**
#    - **Answer:** D) A request to receive real-time updates when data changes
#
# 7. **What is a "schema" in GraphQL?**
#    - **Answer:** B) A description of the data and its structure
#
# 8. **In GraphQL, what is a "resolver"?**
#    - **Answer:** A) A function that resolves a value for a type or field in a schema
#
# 9. **What does a GraphQL query return?**
#    - **Answer:** B) Only the specific data requested by the client
#
# 10. **Which of the following is true about GraphQL?**
#     - **Answer:** B) It allows clients to request exactly the data they need
#
# 11. **What is the purpose of the `type` keyword in a GraphQL schema?**
#     - **Answer:** C) To define the structure of data
#
# 12. **What is the purpose of the `query` keyword in a GraphQL schema?**
#     - **Answer:** B) To define the entry points for reading data
#
# 13. **What is the purpose of the `mutation` keyword in a GraphQL schema?**
#     - **Answer:** C) To define the entry points for modifying data
#
# 14. **What is the purpose of the `subscription` keyword in a GraphQL schema?**
#     - **Answer:** D) To define the entry points for subscribing to data changes
#
# 15. **In GraphQL, what is an "enum"?**
#     - **Answer:** C) A special type that represents a set of constant values
#
# 16. **What is the purpose of the `!` symbol in a GraphQL schema?**
#     - **Answer:** B) To indicate that a field is non-nullable
#
# 17. **What is the purpose of the `input` keyword in a GraphQL schema?**
#     - **Answer:** B) To define the input types for mutations
#
# 18. **What is the difference between `List` and `Non-Null` types in GraphQL?**
#     - **Answer:** A) List represents a collection of values, Non-Null indicates a value cannot be null
#
# 19. **Which of the following is NOT a valid GraphQL operation type?**
#     - **Answer:** D) Procedure
#
# 20. **What is the purpose of the `@` symbol in a GraphQL query?**
#     - **Answer:** B) To define a directive

# %% [markdown]
# ### React Technical MCQs with Answers:
#
# 1. **What is the purpose of `useState` hook in React?**
#    - A) To manage side effects
#    - B) To create a context
#    - C) To add state to functional components
#    - D) To handle events
#    - **Answer:** C) To add state to functional components
#
# 2. **How do you pass props to a component in React?**
#    - A) Using the `context` API
#    - B) Using the `props` attribute in JSX
#    - C) Using the `state` attribute
#    - D) Using the `ref` attribute
#    - **Answer:** B) Using the `props` attribute in JSX
#
# 3. **Which method is used to update the state in a React component?**
#    - A) this.updateState()
#    - B) this.setState()
#    - C) this.modifyState()
#    - D) this.changeState()
#    - **Answer:** B) this.setState()
#
# 4. **What is the purpose of the `useEffect` hook?**
#    - A) To add state to functional components
#    - B) To handle events
#    - C) To perform side effects in functional components
#    - D) To create a context
#    - **Answer:** C) To perform side effects in functional components
#
# 5. **How do you conditionally render a component in React?**
#    - A) Using a switch statement
#    - B) Using the ternary operator
#    - C) Using a for loop
#    - D) Using the `setState` method
#    - **Answer:** B) Using the ternary operator
#
# 6. **What is the purpose of `React.Fragment`?**
#    - A) To manage state
#    - B) To handle events
#    - C) To group multiple elements without adding extra nodes to the DOM
#    - D) To create a context
#    - **Answer:** C) To group multiple elements without adding extra nodes to the DOM
#
# 7. **How can you create a context in React?**
#    - A) Using `createContext` function
#    - B) Using `useState` hook
#    - C) Using `useEffect` hook
#    - D) Using `useRef` hook
#    - **Answer:** A) Using `createContext` function
#
# 8. **What is a pure component in React?**
#    - A) A component that cannot have state
#    - B) A component that cannot accept props
#    - C) A component that implements `shouldComponentUpdate` with a shallow prop and state comparison
#    - D) A component that does not render any UI
#    - **Answer:** C) A component that implements `shouldComponentUpdate` with a shallow prop and state comparison
#
# 9. **Which hook can be used to manage a component’s state?**
#    - A) useEffect
#    - B) useReducer
#    - C) useRef
#    - D) useContext
#    - **Answer:** B) useReducer
#
# 10. **What is the purpose of the `useRef` hook?**
#     - A) To add state to functional components
#     - B) To perform side effects in functional components
#     - C) To persist values across renders without causing re-renders
#     - D) To create a context
#     - **Answer:** C) To persist values across renders without causing re-renders
#
# 11. **How can you optimize performance in a React application?**
#     - A) By using `shouldComponentUpdate` lifecycle method
#     - B) By using the `useEffect` hook
#     - C) By using the `useState` hook
#     - D) By using the `useRef` hook
#     - **Answer:** A) By using `shouldComponentUpdate` lifecycle method
#
# 12. **What does the `useCallback` hook do in React?**
#     - A) It creates a context
#     - B) It persists values across renders
#     - C) It memoizes a callback function
#     - D) It adds state to functional components
#     - **Answer:** C) It memoizes a callback function
#
# 13. **Which lifecycle method is called just before a component is unmounted?**
#     - A) componentDidMount
#     - B) componentDidUpdate
#     - C) componentWillUnmount
#     - D) componentWillMount
#     - **Answer:** C) componentWillUnmount
#
# 14. **What is the purpose of the `useMemo` hook?**
#     - A) To add state to functional components
#     - B) To perform side effects
#     - C) To memoize a value
#     - D) To create a context
#     - **Answer:** C) To memoize a value
#
# 15. **How do you handle form inputs in React?**
#     - A) By using `setState` method
#     - B) By using controlled components
#     - C) By using the `useEffect` hook
#     - D) By using the `createContext` function
#     - **Answer:** B) By using controlled components
#
# 16. **What is the purpose of the `useReducer` hook in React?**
#     - A) To manage side effects
#     - B) To add state to functional components
#     - C) To handle complex state logic
#     - D) To create a context
#     - **Answer:** C) To handle complex state logic
#
# 17. **Which lifecycle method is invoked immediately after updating occurs?**
#     - A) componentWillUpdate
#     - B) componentDidUpdate
#     - C) componentDidMount
#     - D) componentWillUnmount
#     - **Answer:** B) componentDidUpdate
#
# 18. **What is the purpose of the `ReactDOM.render()` method?**
#     - A) To create a new component
#     - B) To update the state
#     - C) To render a React element into the DOM
#     - D) To handle events
#     - **Answer:** C) To render a React element into the DOM
#
# 19. **How can you prevent a component from re-rendering in React?**
#     - A) By using `componentWillUnmount` method
#     - B) By using `React.memo`
#     - C) By using `useEffect` hook
#     - D) By using `useState` hook
#     - **Answer:** B) By using `React.memo`
#
# 20. **What does `ReactDOM.hydrate()` do?**
#     - A) It renders a React element into the DOM
#     - B) It updates the state
#     - C) It hydrates a server-rendered container
#     - D) It creates a new component
#     - **Answer:** C) It hydrates a server-rendered container
#
# 21. **What is the purpose of `React.StrictMode`?**
#     - A) To add state to functional components
#     - B) To catch potential problems in an application
#     - C) To handle events
#     - D) To create a context
#     - **Answer:** B) To catch potential problems in an application
#
# 22. **How can you handle side effects in functional components?**
#     - A) By using `useState` hook
#     - B) By using `useEffect` hook
#     - C) By using `useRef` hook
#     - D) By using `useContext` hook
#     - **Answer:** B) By using `useEffect` hook
#
# 23. **What does `ReactDOM.createPortal` do?**
#     - A) It creates a context
#     - B) It handles events
#     - C) It renders children into a DOM node outside the parent component
#     - D) It adds state to functional components
#     - **Answer:** C) It renders children into a DOM node outside the parent component
#
# 24. **Which hook is used to create a mutable object in functional components?**
#     - A) useState
#     - B) useEffect
#     - C) useRef
#     - D) useReducer
#     - **Answer:** C) useRef
#
# 25. **How can you handle asynchronous operations in React?**
#     - A) By using the `setState` method
#     - B) By using `async` and `await`
#     - C) By using the `useEffect` hook
#     - D) By using `useRef` hook
#     - **Answer:** B) By using `async` and `await`
#
# 26. **What is the purpose of the `key` attribute in React?**
#     - A) To handle events
#     - B) To manage state
#     - C) To uniquely identify elements
#     - D) To create a context
#     - **Answer:** C) To uniquely identify elements
#
# 27. **Which lifecycle method is called when the component is first added to the DOM?**
#     - A) componentWillMount
#     - B) componentDidMount
#     - C) componentDidUpdate
#     - D) componentWillUnmount
#     - **Answer:** B) componentDidMount
#
# 28. **How do you access the state in a functional component?**
#     - A) Using `this.state`
#     - B) Using `props`
#     - C) Using `useState` hook
#     - D) Using `context`
#     - **Answer:** C) Using `useState` hook
#
# 29. **What is the purpose of `React.memo`?**
#     - A) To handle events
#     - B) To manage state
#     - C) To memoize a component to prevent unnecessary re-renders
#     - D) To create a context
#     - **Answer:** C) To memoize a
#
#  component to prevent unnecessary re-renders
#
# 30. **Which hook is used to fetch data in a functional component?**
#     - A) useState
#     - B) useEffect
#     - C) useReducer
#     - D) useRef
#     - **Answer:** B) useEffect

# %% [markdown]
# ### React Technical MCQs with Answers (Set 2):
#
# 1. **What does `ReactDOM.createRoot` do?**
#    - A) Renders a React element into the DOM
#    - B) Creates a new component
#    - C) Manages state
#    - D) Initializes a React application with Concurrent Mode
#    - **Answer:** D) Initializes a React application with Concurrent Mode
#
# 2. **How do you force a component to re-render?**
#    - A) Using `forceRender()`
#    - B) Using `forceUpdate()`
#    - C) Using `reRender()`
#    - D) Using `this.setState({})`
#    - **Answer:** B) Using `forceUpdate()`
#
# 3. **What is the purpose of `React.lazy`?**
#    - A) To add state to functional components
#    - B) To handle events
#    - C) To lazy load a component
#    - D) To create a context
#    - **Answer:** C) To lazy load a component
#
# 4. **Which hook can be used to access context in a functional component?**
#    - A) useState
#    - B) useContext
#    - C) useEffect
#    - D) useReducer
#    - **Answer:** B) useContext
#
# 5. **What does `React.Suspense` do?**
#    - A) Manages state
#    - B) Handles events
#    - C) Wraps lazy-loaded components to handle loading states
#    - D) Creates a context
#    - **Answer:** C) Wraps lazy-loaded components to handle loading states
#
# 6. **What is the purpose of the `defaultProps` property in a React component?**
#    - A) To define default values for props
#    - B) To handle state updates
#    - C) To create a context
#    - D) To manage side effects
#    - **Answer:** A) To define default values for props
#
# 7. **How can you memoize a function in React?**
#    - A) Using `useState`
#    - B) Using `useMemo`
#    - C) Using `useCallback`
#    - D) Using `useEffect`
#    - **Answer:** C) Using `useCallback`
#
# 8. **Which method in React is used to handle errors in a component tree?**
#    - A) componentDidCatch
#    - B) componentWillCatch
#    - C) componentDidError
#    - D) componentWillError
#    - **Answer:** A) componentDidCatch
#
# 9. **What does the `key` attribute help React with?**
#    - A) Identifying which items have changed, are added, or removed
#    - B) Handling events
#    - C) Managing state
#    - D) Creating a context
#    - **Answer:** A) Identifying which items have changed, are added, or removed
#
# 10. **How do you handle errors in React functional components?**
#     - A) Using `componentDidCatch`
#     - B) Using `ErrorBoundaries`
#     - C) Using `useError`
#     - D) Using `useEffect`
#     - **Answer:** B) Using `ErrorBoundaries`
#
# 11. **What is the purpose of `contextType` in a class component?**
#     - A) To manage state
#     - B) To create a context
#     - C) To access the nearest current value of a context type
#     - D) To handle events
#     - **Answer:** C) To access the nearest current value of a context type
#
# 12. **How do you define a state variable in a class component?**
#     - A) `this.state = { variable: value }`
#     - B) `this.variable = value`
#     - C) `this.setState({ variable: value })`
#     - D) `this.state.variable = value`
#     - **Answer:** A) `this.state = { variable: value }`
#
# 13. **What does `useLayoutEffect` do differently than `useEffect`?**
#     - A) Runs after the DOM is painted
#     - B) Runs synchronously after all DOM mutations
#     - C) Runs during the render phase
#     - D) Runs before the DOM is updated
#     - **Answer:** B) Runs synchronously after all DOM mutations
#
# 14. **How do you handle asynchronous data fetching in React?**
#     - A) Using `componentDidMount`
#     - B) Using `useEffect` with async/await
#     - C) Using `setState`
#     - D) Using `componentWillMount`
#     - **Answer:** B) Using `useEffect` with async/await
#
# 15. **How do you update a value in an array state in a functional component?**
#     - A) Directly modifying the array
#     - B) Using `setState` method
#     - C) Using `spread operator` with `useState`
#     - D) Using `useEffect`
#     - **Answer:** C) Using `spread operator` with `useState`
#
# 16. **Which hook allows you to perform side effects in functional components?**
#     - A) useState
#     - B) useEffect
#     - C) useContext
#     - D) useReducer
#     - **Answer:** B) useEffect
#
# 17. **What does the `ref` attribute do in React?**
#     - A) Creates a new component
#     - B) Manages state
#     - C) Provides a way to access the DOM directly
#     - D) Handles events
#     - **Answer:** C) Provides a way to access the DOM directly
#
# 18. **How do you handle conditional rendering in React?**
#     - A) Using `if-else` statements
#     - B) Using the `&&` operator
#     - C) Using ternary operators
#     - D) All of the above
#     - **Answer:** D) All of the above
#
# 19. **How can you optimize rendering of a list of items in React?**
#     - A) Using `useEffect`
#     - B) Using `shouldComponentUpdate`
#     - C) Using `key` prop
#     - D) Using `useMemo`
#     - **Answer:** C) Using `key` prop
#
# 20. **Which hook allows you to return a memoized value in a functional component?**
#     - A) useState
#     - B) useEffect
#     - C) useCallback
#     - D) useMemo
#     - **Answer:** D) useMemo
#
# 21. **What does `React.cloneElement` do?**
#     - A) Creates a new component
#     - B) Clones and returns a new React element
#     - C) Handles events
#     - D) Manages state
#     - **Answer:** B) Clones and returns a new React element
#
# 22. **How do you manage focus in a functional component?**
#     - A) Using `useState`
#     - B) Using `useEffect`
#     - C) Using `useRef`
#     - D) Using `useContext`
#     - **Answer:** C) Using `useRef`
#
# 23. **What is the purpose of the `React.Children` utility?**
#     - A) To manage state
#     - B) To handle events
#     - C) To provide utility functions for dealing with `this.props.children`
#     - D) To create a context
#     - **Answer:** C) To provide utility functions for dealing with `this.props.children`
#
# 24. **How do you handle event binding in React class components?**
#     - A) Using arrow functions in the render method
#     - B) Using `bind` in the constructor
#     - C) Using inline functions in JSX
#     - D) All of the above
#     - **Answer:** D) All of the above
#
# 25. **What is the purpose of `getDerivedStateFromProps` in React?**
#     - A) To handle state updates based on props
#     - B) To create a context
#     - C) To manage side effects
#     - D) To handle events
#     - **Answer:** A) To handle state updates based on props
#
# 26. **Which hook can you use to reduce performance bottlenecks in rendering lists?**
#     - A) useState
#     - B) useEffect
#     - C) useMemo
#     - D) useReducer
#     - **Answer:** C) useMemo
#
# 27. **How do you set default props in a React component?**
#     - A) Using `propTypes`
#     - B) Using `defaultProps`
#     - C) Using `initialProps`
#     - D) Using `staticProps`
#     - **Answer:** B) Using `defaultProps`
#
# 28. **What is the purpose of `componentDidCatch` in React?**
#     - A) To manage state
#     - B) To handle side effects
#     - C) To catch errors in a component tree
#     - D) To handle events
#     - **Answer:** C) To catch errors in a component tree
#
# 29. **How do you share logic between React components?**
#     - A) Using render props
#     - B) Using higher-order components (HOCs)
#     - C) Using custom hooks
#     - D) All of the above
#     - **Answer:** D) All of the above
#
# 30. **What does `React.forwardRef` do?**
#     - A) Manages state
#     - B) Creates a context
#     - C) Forwards a ref to a child component
#     - D) Handles events
#     - **Answer:** C) Forwards a ref to a child component

# %% [markdown]
# ### React Conceptual MCQs with Answers:
#
# 1. **What is the primary use of React?**
#    - A) Building server-side applications
#    - B) Building user interfaces
#    - C) Database management
#    - D) Network security
#    - **Answer:** B) Building user interfaces
#
# 2. **Who developed React?**
#    - A) Google
#    - B) Facebook
#    - C) Microsoft
#    - D) Amazon
#    - **Answer:** B) Facebook
#
# 3. **What does JSX stand for in React?**
#    - A) JavaScript XML
#    - B) Java Syntax Extension
#    - C) JavaScript Execution
#    - D) Java Source XML
#    - **Answer:** A) JavaScript XML
#
# 4. **What is a React component?**
#    - A) A reusable piece of UI
#    - B) A type of database entity
#    - C) A server-side function
#    - D) A CSS style rule
#    - **Answer:** A) A reusable piece of UI
#
# 5. **What is the purpose of the `render()` method in a React component?**
#    - A) To initialize state
#    - B) To update the DOM
#    - C) To define the component's UI
#    - D) To handle events
#    - **Answer:** C) To define the component's UI
#
# 6. **What is "state" in a React component?**
#    - A) A constant value
#    - B) A variable that determines the component's behavior and rendering
#    - C) A method to handle events
#    - D) A CSS class
#    - **Answer:** B) A variable that determines the component's behavior and rendering
#
# 7. **What does "props" stand for in React?**
#    - A) Properties
#    - B) Propositions
#    - C) Prototypes
#    - D) Promises
#    - **Answer:** A) Properties
#
# 8. **How can you update the state in a React component?**
#    - A) Using the `updateState` method
#    - B) Directly modifying the state object
#    - C) Using the `setState` method
#    - D) Using the `render` method
#    - **Answer:** C) Using the `setState` method
#
# 9. **What is the virtual DOM in React?**
#    - A) A virtual representation of the actual DOM
#    - B) A server-side rendering technique
#    - C) A real-time data synchronization method
#    - D) A type of state management
#    - **Answer:** A) A virtual representation of the actual DOM
#
# 10. **What lifecycle method is called after a component is rendered for the first time?**
#     - A) componentDidMount
#     - B) componentWillMount
#     - C) componentDidUpdate
#     - D) componentWillUpdate
#     - **Answer:** A) componentDidMount
#
# 11. **What does the `shouldComponentUpdate` lifecycle method do?**
#     - A) It controls whether a component should re-render
#     - B) It initializes state
#     - C) It handles events
#     - D) It updates the DOM
#     - **Answer:** A) It controls whether a component should re-render
#
# 12. **What is a pure component in React?**
#     - A) A component that only accepts props
#     - B) A component that does not have a state
#     - C) A component that does not render any UI
#     - D) A component that implements `shouldComponentUpdate` with a shallow prop and state comparison
#     - **Answer:** D) A component that implements `shouldComponentUpdate` with a shallow prop and state comparison
#
# 13. **What is the purpose of `React.Fragment`?**
#     - A) To create a reusable piece of UI
#     - B) To group multiple elements without adding extra nodes to the DOM
#     - C) To manage state
#     - D) To handle side effects
#     - **Answer:** B) To group multiple elements without adding extra nodes to the DOM
#
# 14. **How can you create a context in React?**
#     - A) Using the `createContext` function
#     - B) Using the `useContext` hook
#     - C) Both A and B
#     - D) Neither A nor B
#     - **Answer:** C) Both A and B
#
# 15. **What is a hook in React?**
#     - A) A way to handle events
#     - B) A function that lets you use state and other React features in functional components
#     - C) A method for fetching data
#     - D) A CSS property
#     - **Answer:** B) A function that lets you use state and other React features in functional components
#
# 16. **Which hook is used to add state to a functional component?**
#     - A) useState
#     - B) useEffect
#     - C) useReducer
#     - D) useContext
#     - **Answer:** A) useState
#
# 17. **What is the purpose of the `useEffect` hook?**
#     - A) To add state to a functional component
#     - B) To manage side effects in functional components
#     - C) To create a context
#     - D) To handle events
#     - **Answer:** B) To manage side effects in functional components
#
# 18. **How can you pass data from a parent component to a child component in React?**
#     - A) Using state
#     - B) Using props
#     - C) Using context
#     - D) Using hooks
#     - **Answer:** B) Using props
#
# 19. **What is the purpose of the `useRef` hook?**
#     - A) To manage state
#     - B) To manage side effects
#     - C) To persist values across renders without causing re-renders
#     - D) To create a context
#     - **Answer:** C) To persist values across renders without causing re-renders
#
# 20. **What does SSR stand for in the context of React?**
#     - A) Server-Side Rendering
#     - B) State Synchronization Routine
#     - C) Static Site Rendering
#     - D) Server-Side Request
#     - **Answer:** A) Server-Side Rendering
#
# 21. **What does the term "React Element" refer to?**
#     - A) A JavaScript object that represents a DOM node or component
#     - B) A function that adds state to functional components
#     - C) A lifecycle method
#     - D) A CSS property
#     - **Answer:** A) A JavaScript object that represents a DOM node or component
#
# 22. **What is the main advantage of using a virtual DOM in React?**
#     - A) It enhances CSS capabilities
#     - B) It reduces the cost of updates to the real DOM
#     - C) It allows for server-side rendering
#     - D) It improves database management
#     - **Answer:** B) It reduces the cost of updates to the real DOM
#
# 23. **What is the role of the `componentDidCatch` lifecycle method?**
#     - A) To catch errors in any components below it in the tree
#     - B) To manage state
#     - C) To handle events
#     - D) To initialize props
#     - **Answer:** A) To catch errors in any components below it in the tree
#
# 24. **What does "lifting state up" mean in React?**
#     - A) Moving state to a parent component to share between child components
#     - B) Moving state to a child component
#     - C) Converting state to props
#     - D) Updating the virtual DOM
#     - **Answer:** A) Moving state to a parent component to share between child components
#
# 25. **What is the purpose of `ReactDOM`?**
#     - A) It provides DOM-specific methods that can be used at the top level of a web app
#     - B) It is used for managing component state
#     - C) It is used to define prop types
#     - D) It provides lifecycle methods
#     - **Answer:** A) It provides DOM-specific methods that can be used at the top level of a web app
#
# 26. **What does the `componentDidUpdate` lifecycle method do?**
#     - A) It is called immediately after updating occurs
#     - B) It is called before the component mounts
#     - C) It is called when the component is unmounted
#     - D) It is called when props are received
#     - **Answer:** A) It is called immediately after updating occurs
#
# 27. **What is the purpose of `React.Children` utility?**
#     - A) To provide utilities for dealing with `this.props.children`
#     - B) To create context
#     - C) To manage state
#     - D) To handle events
#     - **Answer:** A) To provide utilities for dealing with `this.props.children`
#
# 28. **What is the difference between a class component and a functional component?**
#     - A) Class components can have state, functional components cannot
#     - B) Class components use lifecycle methods, functional components use hooks
#     - C) Functional components are simpler and primarily focus on presenting UI
#     - D) All of the above
#     - **Answer:** D) All of the above
#
# 29. **What is the purpose of `propTypes` in React?**
#     - A) To validate props passed to a component
#     - B) To manage state
#     - C) To handle events
#     - D) To create context
#     - **Answer:** A) To validate props passed to a component
#
# 30. **What does `
#
# useReducer` hook do?**
#     - A) Adds state to functional components
#     - B) Manages side effects
#     - C) Handles more complex state logic compared to `useState`
#     - D) Creates context
#     - **Answer:** C) Handles more complex state logic compared to `useState`
#
# These conceptual MCQs cover a range of fundamental React concepts, including hooks, lifecycle methods, state management, and component structure.

# %% [markdown]
# ### React, MongoDB, GraphQL, and Node.js MCQs with Answers:
#
# 1. **How do you connect a React application to a MongoDB database?**
#    - A) Directly using MongoDB client
#    - B) Through a backend server like Node.js
#    - C) By including MongoDB SDK in React
#    - D) Using WebSockets
#    - **Answer:** B) Through a backend server like Node.js
#
# 2. **What is the purpose of Mongoose in a Node.js application?**
#    - A) To handle state in React
#    - B) To provide a schema-based solution to model MongoDB data
#    - C) To manage component lifecycle
#    - D) To create a REST API
#    - **Answer:** B) To provide a schema-based solution to model MongoDB data
#
# 3. **Which method is used to find all documents in a MongoDB collection using Mongoose?**
#    - A) `Collection.getAll()`
#    - B) `Model.findAll()`
#    - C) `Model.find()`
#    - D) `Collection.retrieve()`
#    - **Answer:** C) Model.find()
#
# 4. **What is GraphQL?**
#    - A) A query language for APIs
#    - B) A database management system
#    - C) A state management library
#    - D) A CSS framework
#    - **Answer:** A) A query language for APIs
#
# 5. **Which library is commonly used to integrate GraphQL in a React application?**
#    - A) Redux
#    - B) Apollo Client
#    - C) Axios
#    - D) Mongoose
#    - **Answer:** B) Apollo Client
#
# 6. **What is the purpose of the `typeDefs` in a GraphQL server setup?**
#    - A) To define the types and structure of data
#    - B) To handle HTTP requests
#    - C) To manage state in React
#    - D) To connect to the database
#    - **Answer:** A) To define the types and structure of data
#
# 7. **How do you create a new document in a MongoDB collection using Mongoose?**
#    - A) `Model.insert(data)`
#    - B) `Model.create(data)`
#    - C) `Model.add(data)`
#    - D) `Model.save(data)`
#    - **Answer:** B) Model.create(data)
#
# 8. **Which hook is used to fetch data from a GraphQL API in a React component?**
#    - A) useState
#    - B) useEffect
#    - C) useQuery
#    - D) useMutation
#    - **Answer:** C) useQuery
#
# 9. **What is a resolver in GraphQL?**
#    - A) A function that resolves a value for a type or field in a schema
#    - B) A method for handling HTTP requests
#    - C) A state management tool
#    - D) A library for managing CSS
#    - **Answer:** A) A function that resolves a value for a type or field in a schema
#
# 10. **How do you update a document in MongoDB using Mongoose?**
#     - A) `Model.modify(data)`
#     - B) `Model.updateOne(filter, data)`
#     - C) `Model.changeOne(filter, data)`
#     - D) `Model.editOne(filter, data)`
#     - **Answer:** B) Model.updateOne(filter, data)
#
# 11. **What is Apollo Client used for in React?**
#     - A) State management
#     - B) Connecting to a MongoDB database
#     - C) Making GraphQL queries and mutations
#     - D) Handling form submissions
#     - **Answer:** C) Making GraphQL queries and mutations
#
# 12. **Which command is used to install Mongoose in a Node.js project?**
#     - A) `npm install mongoose`
#     - B) `npm install mongodb`
#     - C) `npm install mongo`
#     - D) `npm install mongooseDB`
#     - **Answer:** A) npm install mongoose
#
# 13. **What is the purpose of the `useMutation` hook in Apollo Client?**
#     - A) To fetch data
#     - B) To manage local state
#     - C) To execute GraphQL mutations
#     - D) To create context
#     - **Answer:** C) To execute GraphQL mutations
#
# 14. **How do you start a Node.js server?**
#     - A) `node server.js`
#     - B) `npm start`
#     - C) `node start`
#     - D) `node app.js`
#     - **Answer:** A) node server.js
#
# 15. **What is the role of the `context` object in GraphQL?**
#     - A) To handle state in React
#     - B) To provide a shared context to all resolvers
#     - C) To define the schema
#     - D) To handle HTTP requests
#     - **Answer:** B) To provide a shared context to all resolvers
#
# 16. **How do you delete a document in MongoDB using Mongoose?**
#     - A) `Model.remove(filter)`
#     - B) `Model.deleteOne(filter)`
#     - C) `Model.drop(filter)`
#     - D) `Model.destroy(filter)`
#     - **Answer:** B) Model.deleteOne(filter)
#
# 17. **What is the purpose of the `useEffect` hook in React when dealing with data fetching?**
#     - A) To manage local state
#     - B) To perform side effects such as data fetching
#     - C) To create context
#     - D) To handle events
#     - **Answer:** B) To perform side effects such as data fetching
#
# 18. **How do you define a GraphQL schema?**
#     - A) Using `typeDefs`
#     - B) Using `resolvers`
#     - C) Using `schemaTypes`
#     - D) Using `graphqlTypes`
#     - **Answer:** A) Using typeDefs
#
# 19. **Which method is used to connect to a MongoDB database using Mongoose?**
#     - A) `Mongoose.connect()`
#     - B) `Mongoose.createConnection()`
#     - C) `Mongoose.open()`
#     - D) `Mongoose.init()`
#     - **Answer:** A) Mongoose.connect()
#
# 20. **What is the purpose of the `ApolloProvider` component in a React application?**
#     - A) To fetch data
#     - B) To handle form submissions
#     - C) To provide the Apollo Client instance to the React component tree
#     - D) To manage local state
#     - **Answer:** C) To provide the Apollo Client instance to the React component tree
#
# 21. **What is Node.js?**
#     - A) A frontend framework
#     - B) A JavaScript runtime built on Chrome's V8 engine
#     - C) A CSS library
#     - D) A database management system
#     - **Answer:** B) A JavaScript runtime built on Chrome's V8 engine
#
# 22. **How do you define a model in Mongoose?**
#     - A) Using `Mongoose.define()`
#     - B) Using `Mongoose.model()`
#     - C) Using `Mongoose.create()`
#     - D) Using `Mongoose.schema()`
#     - **Answer:** B) Using Mongoose.model()
#
# 23. **What is the purpose of the `resolver` function in GraphQL?**
#     - A) To define the schema
#     - B) To handle HTTP requests
#     - C) To resolve the value of a field in a GraphQL query
#     - D) To manage local state
#     - **Answer:** C) To resolve the value of a field in a GraphQL query
#
# 24. **How do you perform authentication in a React application?**
#     - A) Using JWT
#     - B) Using Context API
#     - C) Using local storage
#     - D) Using Apollo Client
#     - **Answer:** A) Using JWT
#
# 25. **How do you execute a GraphQL query in a React component using Apollo Client?**
#     - A) Using `useQuery` hook
#     - B) Using `useMutation` hook
#     - C) Using `useApolloClient` hook
#     - D) Using `useState` hook
#     - **Answer:** A) Using useQuery hook
#
# 26. **Which command is used to install Apollo Client in a React project?**
#     - A) `npm install apollo-client`
#     - B) `npm install @apollo/client graphql`
#     - C) `npm install graphql-apollo`
#     - D) `npm install apollo`
#     - **Answer:** B) npm install @apollo/client graphql
#
# 27. **What is the purpose of `typeDefs` in a GraphQL schema?**
#     - A) To define the types and structure of data
#     - B) To handle HTTP requests
#     - C) To manage state in React
#     - D) To connect to the database
#     - **Answer:** A) To define the types and structure of data
#
# 28. **What does REST stand for?**
#     - A) Representational State Transfer
#     - B) Remote Execution Service Technology
#     - C) Reliable Server Transactions
#     - D) Remote System Testing
#     - **Answer:** A) Representational State Transfer
#
# 29. **Which HTTP method is used to update an existing resource in a REST API?**
#     - A) GET
#     - B) POST
#     - C) PUT
#     - D) DELETE
#     - **Answer:** C) PUT
#
# 30. **How do you create a RESTful API in Node.js?**
#     - A) Using Express.js
#     - B) Using
#
#  Mongoose
#     - C) Using Apollo Server
#     - D) Using MongoDB
#     - **Answer:** A) Using Express.js
#
# 31. **What is the purpose of the `body-parser` middleware in Express.js?**
#     - A) To parse incoming request bodies in a middleware
#     - B) To manage state in a React application
#     - C) To handle GraphQL queries
#     - D) To connect to a MongoDB database
#     - **Answer:** A) To parse incoming request bodies in a middleware
#
# 32. **How do you install Express.js in a Node.js project?**
#     - A) `npm install express`
#     - B) `npm install expressjs`
#     - C) `npm install express.js`
#     - D) `npm install express-server`
#     - **Answer:** A) npm install express
#
# 33. **What is the purpose of the `mongoose.Schema` class?**
#     - A) To define the structure of a document
#     - B) To handle HTTP requests
#     - C) To manage state in React
#     - D) To create a REST API
#     - **Answer:** A) To define the structure of a document
#
# 34. **How do you create a GraphQL server in Node.js?**
#     - A) Using Apollo Server
#     - B) Using Express.js
#     - C) Using Mongoose
#     - D) Using MongoDB
#     - **Answer:** A) Using Apollo Server
#
# 35. **Which command is used to install Apollo Server in a Node.js project?**
#     - A) `npm install apollo-server`
#     - B) `npm install @apollo/server`
#     - C) `npm install graphql-apollo`
#     - D) `npm install apollo-server-express`
#     - **Answer:** A) npm install apollo-server
#
# 36. **How do you define a resolver in Apollo Server?**
#     - A) Using `const resolvers = { Query: { ... }, Mutation: { ... } }`
#     - B) Using `const resolvers = { getQuery: { ... }, postMutation: { ... } }`
#     - C) Using `const resolvers = { queryResolver: { ... }, mutationResolver: { ... } }`
#     - D) Using `const resolvers = { QueryResolver: { ... }, MutationResolver: { ... } }`
#     - **Answer:** A) Using const resolvers = { Query: { ... }, Mutation: { ... } }
#
# 37. **What is the purpose of the `GraphQLObjectType` in GraphQL?**
#     - A) To define the structure of an object type in the schema
#     - B) To handle HTTP requests
#     - C) To manage state in React
#     - D) To connect to the database
#     - **Answer:** A) To define the structure of an object type in the schema
#
# 38. **How do you start an Apollo Server?**
#     - A) `server.listen()`
#     - B) `server.start()`
#     - C) `server.begin()`
#     - D) `server.run()`
#     - **Answer:** A) server.listen()
#
# 39. **What is the purpose of `express-graphql`?**
#     - A) To integrate GraphQL with Express.js
#     - B) To manage state in React
#     - C) To handle MongoDB connections
#     - D) To create RESTful APIs
#     - **Answer:** A) To integrate GraphQL with Express.js
#
# 40. **How do you make a GraphQL query using Apollo Client in a React component?**
#     - A) Using `useQuery` hook
#     - B) Using `useMutation` hook
#     - C) Using `useApolloClient` hook
#     - D) Using `useEffect` hook
#     - **Answer:** A) Using useQuery hook
#
# 41. **What is the purpose of the `graphqlHTTP` middleware in Express.js?**
#     - A) To handle GraphQL queries and mutations
#     - B) To manage state in React
#     - C) To handle MongoDB connections
#     - D) To create RESTful APIs
#     - **Answer:** A) To handle GraphQL queries and mutations
#
# 42. **Which command is used to install `express-graphql` in a Node.js project?**
#     - A) `npm install express-graphql`
#     - B) `npm install graphql-express`
#     - C) `npm install graphql-server`
#     - D) `npm install express-graphql-server`
#     - **Answer:** A) npm install express-graphql
#
# 43. **What is the purpose of the `context` function in Apollo Server?**
#     - A) To provide a shared context to all resolvers
#     - B) To handle HTTP requests
#     - C) To manage state in React
#     - D) To connect to the database
#     - **Answer:** A) To provide a shared context to all resolvers
#
# 44. **How do you perform a mutation in a GraphQL API using Apollo Client?**
#     - A) Using `useMutation` hook
#     - B) Using `useQuery` hook
#     - C) Using `useApolloClient` hook
#     - D) Using `useState` hook
#     - **Answer:** A) Using useMutation hook
#
# 45. **How do you define a model in Mongoose?**
#     - A) Using `const model = mongoose.model('ModelName', schema)`
#     - B) Using `const model = mongoose.define('ModelName', schema)`
#     - C) Using `const model = mongoose.create('ModelName', schema)`
#     - D) Using `const model = mongoose.schema('ModelName', schema)`
#     - **Answer:** A) Using const model = mongoose.model('ModelName', schema)
#
# 46. **What is the purpose of `GraphQLSchema` in GraphQL?**
#     - A) To define the structure and types of data
#     - B) To handle HTTP requests
#     - C) To manage state in React
#     - D) To connect to the database
#     - **Answer:** A) To define the structure and types of data
#
# 47. **How do you connect to a MongoDB database in a Node.js application?**
#     - A) `mongoose.connect('mongodb://localhost/mydatabase')`
#     - B) `mongoose.open('mongodb://localhost/mydatabase')`
#     - C) `mongoose.init('mongodb://localhost/mydatabase')`
#     - D) `mongoose.start('mongodb://localhost/mydatabase')`
#     - **Answer:** A) mongoose.connect('mongodb://localhost/mydatabase')
#
# 48. **What is the purpose of the `@apollo/client` package?**
#     - A) To manage local state in a React application
#     - B) To make GraphQL queries and mutations from a React application
#     - C) To connect to a MongoDB database
#     - D) To handle form submissions in React
#     - **Answer:** B) To make GraphQL queries and mutations from a React application
#
# 49. **How do you handle errors in a GraphQL resolver?**
#     - A) By throwing an error in the resolver function
#     - B) By using a try/catch block in the resolver function
#     - C) By using a middleware to catch errors
#     - D) Both A and B
#     - **Answer:** D) Both A and B
#
# 50. **How do you perform a subscription in GraphQL using Apollo Client?**
#     - A) Using `useSubscription` hook
#     - B) Using `useQuery` hook
#     - C) Using `useMutation` hook
#     - D) Using `useApolloClient` hook
#     - **Answer:** A) Using useSubscription hook

# %% [markdown]
# ### Redux and Redux Toolkit MCQs with Answers
#
# 1. **What is the primary purpose of Redux in a React application?**
#    - A) To handle HTTP requests
#    - B) To manage state globally
#    - C) To manage styles
#    - D) To handle routing
#    - **Answer:** B) To manage state globally
#
# 2. **What is a reducer in Redux?**
#    - A) A function that returns the next state
#    - B) A function that handles HTTP requests
#    - C) A function that manages components
#    - D) A function that performs side effects
#    - **Answer:** A) A function that returns the next state
#
# 3. **How do you create a store in Redux?**
#    - A) `createStore(reducer)`
#    - B) `initializeStore(reducer)`
#    - C) `store.create(reducer)`
#    - D) `new Store(reducer)`
#    - **Answer:** A) createStore(reducer)
#
# 4. **What is the purpose of an action in Redux?**
#    - A) To modify the DOM
#    - B) To describe what happened
#    - C) To manage state locally
#    - D) To handle asynchronous operations
#    - **Answer:** B) To describe what happened
#
# 5. **How do you dispatch an action in Redux?**
#    - A) `store.send(action)`
#    - B) `store.dispatch(action)`
#    - C) `store.action(action)`
#    - D) `store.run(action)`
#    - **Answer:** B) store.dispatch(action)
#
# 6. **What is the `combineReducers` function used for in Redux?**
#    - A) To combine multiple reducers into one
#    - B) To merge states
#    - C) To create actions
#    - D) To handle asynchronous operations
#    - **Answer:** A) To combine multiple reducers into one
#
# 7. **How do you connect a React component to the Redux store?**
#    - A) Using `connect` from `react-redux`
#    - B) Using `useReducer` hook
#    - C) Using `useStore` hook
#    - D) Using `useState` hook
#    - **Answer:** A) Using `connect` from `react-redux`
#
# 8. **What does `mapStateToProps` do in Redux?**
#    - A) Maps the state to the component’s props
#    - B) Maps actions to the component’s props
#    - C) Dispatches actions
#    - D) Initializes the store
#    - **Answer:** A) Maps the state to the component’s props
#
# 9. **What is Redux Toolkit?**
#    - A) A library for managing HTTP requests
#    - B) A set of tools for efficient Redux development
#    - C) A styling library
#    - D) A routing library
#    - **Answer:** B) A set of tools for efficient Redux development
#
# 10. **How do you create a slice in Redux Toolkit?**
#     - A) `createSlice({ name, initialState, reducers })`
#     - B) `initializeSlice({ name, initialState, reducers })`
#     - C) `new Slice({ name, initialState, reducers })`
#     - D) `slice.create({ name, initialState, reducers })`
#     - **Answer:** A) createSlice({ name, initialState, reducers })
#
# 11. **What is the purpose of `createAsyncThunk` in Redux Toolkit?**
#     - A) To handle synchronous actions
#     - B) To create an async action that can handle side effects
#     - C) To create a reducer
#     - D) To manage styles
#     - **Answer:** B) To create an async action that can handle side effects
#
# 12. **Which hook is used to access the Redux store in a functional component?**
#     - A) `useStore`
#     - B) `useSelector`
#     - C) `useReducer`
#     - D) `useDispatch`
#     - **Answer:** B) useSelector
#
# 13. **Which hook is used to dispatch actions in a functional component?**
#     - A) `useStore`
#     - B) `useSelector`
#     - C) `useReducer`
#     - D) `useDispatch`
#     - **Answer:** D) useDispatch
#
# 14. **What does `configureStore` do in Redux Toolkit?**
#     - A) Sets up a Redux store with good defaults
#     - B) Configures React components
#     - C) Handles HTTP requests
#     - D) Manages CSS
#     - **Answer:** A) Sets up a Redux store with good defaults
#
# 15. **What is the purpose of middleware in Redux?**
#     - A) To handle component rendering
#     - B) To provide a third-party extension point between dispatching an action and the moment it reaches the reducer
#     - C) To manage styles
#     - D) To handle routing
#     - **Answer:** B) To provide a third-party extension point between dispatching an action and the moment it reaches the reducer
#
# 16. **How do you apply middleware to a Redux store?**
#     - A) `applyMiddleware(middleware)`
#     - B) `store.apply(middleware)`
#     - C) `store.middleware(middleware)`
#     - D) `createStore(reducer, applyMiddleware(middleware))`
#     - **Answer:** D) createStore(reducer, applyMiddleware(middleware))
#
# 17. **What does `createSlice` return in Redux Toolkit?**
#     - A) An object containing the slice reducer and action creators
#     - B) Only the slice reducer
#     - C) Only the action creators
#     - D) A new Redux store
#     - **Answer:** A) An object containing the slice reducer and action creators
#
# 18. **How do you integrate Redux DevTools with Redux Toolkit?**
#     - A) It is integrated by default with `configureStore`
#     - B) Using `applyMiddleware`
#     - C) Using `compose`
#     - D) By importing a separate package
#     - **Answer:** A) It is integrated by default with configureStore
#
# 19. **What is the `useSelector` hook used for in Redux?**
#     - A) To select data from the Redux store
#     - B) To dispatch actions
#     - C) To create reducers
#     - D) To handle side effects
#     - **Answer:** A) To select data from the Redux store
#
# 20. **How do you create a Redux action in Redux Toolkit?**
#     - A) Using `createAction`
#     - B) Using `createAsyncThunk`
#     - C) Using `createReducer`
#     - D) Using `createSlice`
#     - **Answer:** A) Using createAction
#
# 21. **What is an action creator in Redux?**
#     - A) A function that creates an action
#     - B) A function that dispatches an action
#     - C) A function that handles HTTP requests
#     - D) A function that manages state
#     - **Answer:** A) A function that creates an action
#
# 22. **How do you combine multiple slices in Redux Toolkit?**
#     - A) Using `combineReducers`
#     - B) Using `createSlice`
#     - C) Using `configureStore`
#     - D) Using `createReducer`
#     - **Answer:** A) Using combineReducers
#
# 23. **What is the purpose of the `extraReducers` field in `createSlice`?**
#     - A) To handle actions defined outside of the slice
#     - B) To define the initial state
#     - C) To create synchronous actions
#     - D) To manage side effects
#     - **Answer:** A) To handle actions defined outside of the slice
#
# 24. **Which function is used to make a slice reducer in Redux Toolkit?**
#     - A) `createReducer`
#     - B) `createSlice`
#     - C) `createStore`
#     - D) `createAction`
#     - **Answer:** B) createSlice
#
# 25. **How do you handle asynchronous operations in Redux?**
#     - A) Using Thunks
#     - B) Using Sagas
#     - C) Using Middleware
#     - D) All of the above
#     - **Answer:** D) All of the above
#
# 26. **How do you access the Redux state in a class component?**
#     - A) Using `connect` and `mapStateToProps`
#     - B) Using `useSelector`
#     - C) Using `useState`
#     - D) Using `useReducer`
#     - **Answer:** A) Using connect and mapStateToProps
#
# 27. **What does `configureStore` from Redux Toolkit accept as an argument?**
#     - A) An object with `reducer`, `middleware`, and `devTools` options
#     - B) Only a reducer
#     - C) An action creator
#     - D) A state
#     - **Answer:** A) An object with reducer, middleware, and devTools options
#
# 28. **What is the role of a selector in Redux?**
#     - A) To select a part of the state
#     - B) To dispatch actions
#     - C) To create reducers
#     - D) To handle side effects
#     - **Answer:** A) To select a part of the state
#
# 29. **How do you handle side effects in Redux?**
#     - A) Using middleware like Redux Thunk or Redux Saga
#     - B) Using reducers
#     - C) Using action creators
#     - D) Using selectors
#     - **Answer:** A) Using middleware like Redux Thunk or Redux Saga
#
# 30. **What is a thunk in Redux?**
#     - A) A function that wraps an expression to delay its evaluation
#     - B) A middleware for handling asynchronous operations
#     - C) A type of action creator
#     - D) A function that manages state
#     - **Answer:** B) A middleware for handling asynchronous operations
#
# 31. **How do you install Redux Toolkit?**
#     - A) `npm install @reduxjs/toolkit`
#     - B) `npm install redux-toolkit`
#     - C) `npm install reduxjs/toolkit`
#     - D) `npm install redux`
#     - **Answer:** A) npm install @reduxjs/toolkit
#
# 32. **What is the `useDispatch` hook used for in Redux?**
#     - A) To dispatch actions
#     - B) To select data from the store
#     - C) To create reducers
#     - D) To manage state locally
#     - **Answer:** A) To dispatch actions
#
# 33. **What is the purpose of `createAction` in Redux Toolkit?**
#     - A) To create an action creator
#     - B) To create a reducer
#     - C) To create a store
#     - D) To create a middleware
#     - **Answer:** A) To create an action creator
#
# 34. **Which function in Redux Toolkit is used to handle synchronous and asynchronous logic inside slices?**
#     - A) `createAsyncThunk`
#     - B) `createSlice`
#     - C) `createReducer`
#     - D) `createAction`
#     - **Answer:** B) createSlice
#
# 35. **How do you install the Redux library in a project?**
#     - A) `npm install redux`
#     - B) `npm install redux-library`
#     - C) `npm install redux-core`
#     - D) `npm install reduxjs`
#     - **Answer:** A) npm install redux
#
# 36. **What is the default state in Redux typically represented by?**
#     - A) An object
#     - B) A string
#     - C) An array
#     - D) A number
#     - **Answer:** A) An object
#
# 37. **What does the `useStore` hook return in Redux?**
#     - A) The Redux store
#     - B) The current state
#     - C) The dispatch function
#     - D) The reducer
#     - **Answer:** A) The Redux store
#
# 38. **How do you handle multiple actions in a reducer?**
#     - A) Using a switch statement
#     - B) Using an if-else statement
#     - C) Using a for loop
#     - D) Using a while loop
#     - **Answer:** A) Using a switch statement
#
# 39. **What is the purpose of `createReducer` in Redux Toolkit?**
#     - A) To create a reducer without switch statements
#     - B) To create an action
#     - C) To create a store
#     - D) To handle side effects
#     - **Answer:** A) To create a reducer without switch statements
#
# 40. **What does the `redux-thunk` middleware do?**
#     - A) Allows action creators to return functions instead of actions
#     - B) Manages state locally
#     - C) Handles HTTP requests
#     - D) Manages component lifecycle
#     - **Answer:** A) Allows action creators to return functions instead of actions
#
# 41. **What is the `Provider` component used for in Redux?**
#     - A) To provide the Redux store to React components
#     - B) To dispatch actions
#     - C) To create reducers
#     - D) To manage state locally
#     - **Answer:** A) To provide the Redux store to React components
#
# 42. **How do you subscribe to the store in a Redux application?**
#     - A) `store.subscribe(listener)`
#     - B) `store.listen(listener)`
#     - C) `store.on(listener)`
#     - D) `store.addListener(listener)`
#     - **Answer:** A) store.subscribe(listener)
#
# 43. **What is the purpose of the `immer` library in Redux Toolkit?**
#     - A) To work with immutable state updates
#     - B) To handle HTTP requests
#     - C) To manage component lifecycle
#     - D) To create action creators
#     - **Answer:** A) To work with immutable state updates
#
# 44. **How do you access the initial state in a reducer function?**
#     - A) As the second argument
#     - B) As the first argument
#     - C) As a global variable
#     - D) Using the `useState` hook
#     - **Answer:** B) As the first argument
#
# 45. **What is the purpose of the `createEntityAdapter` function in Redux Toolkit?**
#     - A) To manage normalized state
#     - B) To create action creators
#     - C) To create reducers
#     - D) To handle side effects
#     - **Answer:** A) To manage normalized state
#
# 46. **Which function in Redux Toolkit helps in creating a slice of the state?**
#     - A) `createSlice`
#     - B) `createAsyncThunk`
#     - C) `createReducer`
#     - D) `createAction`
#     - **Answer:** A) createSlice
#
# 47. **How do you enhance a store with middleware in Redux Toolkit?**
#     - A) Using the `middleware` option in `configureStore`
#     - B) Using `applyMiddleware`
#     - C) Using `createStore`
#     - D) Using `combineReducers`
#     - **Answer:** A) Using the middleware option in configureStore
#
# 48. **What is the default export of the `@reduxjs/toolkit` package?**
#     - A) `configureStore`
#     - B) `createSlice`
#     - C) `createAsyncThunk`
#     - D) `createAction`
#     - **Answer:** A) configureStore
#
# 49. **Which of the following is a middleware that can handle side effects in Redux?**
#     - A) Redux Thunk
#     - B) Redux Saga
#     - C) Redux Observable
#     - D) All of the above
#     - **Answer:** D) All of the above
#
# 50. **What is the key advantage of using Redux Toolkit over vanilla Redux?**
#     - A) Reduces boilerplate code and provides good defaults
#     - B) Handles HTTP requests
#     - C) Manages styles
#     - D) Handles component lifecycle
#     - **Answer:** A) Reduces boilerplate code and provides good defaults

# %% [markdown]
# ### Context API Technical MCQs with Answers
#
# 1. **What is the main purpose of the Context API in React?**
#    - A) To manage component lifecycle
#    - B) To handle global state without prop drilling
#    - C) To handle HTTP requests
#    - D) To manage styles
#    - **Answer:** B) To handle global state without prop drilling
#
# 2. **How do you create a Context in React?**
#    - A) `React.createContext(defaultValue)`
#    - B) `React.initializeContext(defaultValue)`
#    - C) `new ReactContext(defaultValue)`
#    - D) `React.Context(defaultValue)`
#    - **Answer:** A) React.createContext(defaultValue)
#
# 3. **What is the purpose of the `Provider` component in the Context API?**
#    - A) To provide the context value to its children
#    - B) To consume the context value
#    - C) To dispatch actions
#    - D) To handle side effects
#    - **Answer:** A) To provide the context value to its children
#
# 4. **How do you consume a context value in a functional component?**
#    - A) `useContext(MyContext)`
#    - B) `useState(MyContext)`
#    - C) `useReducer(MyContext)`
#    - D) `useEffect(MyContext)`
#    - **Answer:** A) useContext(MyContext)
#
# 5. **Which hook is used to access context values in a functional component?**
#    - A) `useEffect`
#    - B) `useContext`
#    - C) `useState`
#    - D) `useReducer`
#    - **Answer:** B) useContext
#
# 6. **How do you access context values in a class component?**
#    - A) `this.context`
#    - B) `this.useContext`
#    - C) `this.useState`
#    - D) `this.useEffect`
#    - **Answer:** A) this.context
#
# 7. **What must you do to make a class component consume context?**
#    - A) Define a static contextType property
#    - B) Use the useContext hook
#    - C) Define a static context property
#    - D) Use the useState hook
#    - **Answer:** A) Define a static contextType property
#
# 8. **How do you provide a default value for a context?**
#    - A) `React.createContext(defaultValue)`
#    - B) `React.Context(defaultValue)`
#    - C) `React.useContext(defaultValue)`
#    - D) `React.useState(defaultValue)`
#    - **Answer:** A) React.createContext(defaultValue)
#
# 9. **What is the `Consumer` component used for in the Context API?**
#    - A) To consume context values in a class component
#    - B) To consume context values in a functional component
#    - C) To provide context values to its children
#    - D) To create a new context
#    - **Answer:** A) To consume context values in a class component
#
# 10. **How do you nest multiple context providers in a React component tree?**
#     - A) Wrap each provider around its children
#     - B) Use an array of contexts
#     - C) Use a single provider
#     - D) Use the useReducer hook
#     - **Answer:** A) Wrap each provider around its children
#
# 11. **Can you use the Context API to manage complex state logic?**
#     - A) Yes, but it is better to use Redux or another state management library for complex logic
#     - B) No, it can only handle simple state
#     - C) Yes, it is designed for complex state management
#     - D) No, it is only for managing themes
#     - **Answer:** A) Yes, but it is better to use Redux or another state management library for complex logic
#
# 12. **What happens if you use a `Consumer` component outside of a `Provider`?**
#     - A) It will use the default context value
#     - B) It will throw an error
#     - C) It will use the global state
#     - D) It will not render anything
#     - **Answer:** A) It will use the default context value
#
# 13. **How can you update context values?**
#     - A) By passing a new value to the `Provider`
#     - B) By using the `setContext` function
#     - C) By calling `useEffect`
#     - D) By using the `useReducer` hook
#     - **Answer:** A) By passing a new value to the `Provider`
#
# 14. **What is the key advantage of using the Context API over prop drilling?**
#     - A) Reduces the need to pass props through many levels of the component tree
#     - B) Improves performance
#     - C) Simplifies event handling
#     - D) Enhances CSS management
#     - **Answer:** A) Reduces the need to pass props through many levels of the component tree
#
# 15. **What is a drawback of using the Context API for state management?**
#     - A) It can lead to unnecessary re-renders if not used carefully
#     - B) It does not support asynchronous actions
#     - C) It cannot handle large state objects
#     - D) It requires more code than Redux
#     - **Answer:** A) It can lead to unnecessary re-renders if not used carefully
#
# 16. **How do you avoid unnecessary re-renders when using Context API?**
#     - A) By memoizing context values
#     - B) By using `useEffect`
#     - C) By using `useState`
#     - D) By using `useReducer`
#     - **Answer:** A) By memoizing context values
#
# 17. **How do you test components that use Context API?**
#     - A) Wrap the components with the `Provider` in the test
#     - B) Mock the context values
#     - C) Use `useContext` in the test
#     - D) Use `useState` in the test
#     - **Answer:** A) Wrap the components with the Provider in the test
#
# 18. **Can you use the Context API with server-side rendering (SSR)?**
#     - A) Yes, it works with SSR
#     - B) No, it is not compatible with SSR
#     - C) Only with Gatsby
#     - D) Only with Next.js
#     - **Answer:** A) Yes, it works with SSR
#
# 19. **How do you create a dynamic context value that changes based on state?**
#     - A) Use `useState` or `useReducer` in the `Provider` component
#     - B) Use `useEffect` in the `Provider` component
#     - C) Use `useContext` in the `Provider` component
#     - D) Use `useMemo` in the `Provider` component
#     - **Answer:** A) Use useState or useReducer in the Provider component
#
# 20. **What is the `useContext` hook's return value?**
#     - A) The current context value
#     - B) A function to update the context value
#     - C) An array of context values
#     - D) A reference to the context object
#     - **Answer:** A) The current context value
#
# 21. **How do you share context values across different modules in a React application?**
#     - A) By exporting the context object and provider
#     - B) By using global variables
#     - C) By using props
#     - D) By using local storage
#     - **Answer:** A) By exporting the context object and provider
#
# 22. **What is the difference between context and props?**
#     - A) Context is for global state, props are for local state
#     - B) Context can be consumed anywhere, props must be passed explicitly
#     - C) Context is immutable, props are mutable
#     - D) Context is synchronous, props are asynchronous
#     - **Answer:** B) Context can be consumed anywhere, props must be passed explicitly
#
# 23. **How do you handle multiple contexts in a single component?**
#     - A) Use multiple `useContext` hooks
#     - B) Use a single context
#     - C) Use nested `Provider` components
#     - D) Use `useReducer`
#     - **Answer:** A) Use multiple useContext hooks
#
# 24. **What is contextType in React?**
#     - A) A way to consume context in class components
#     - B) A way to create context
#     - C) A way to update context
#     - D) A way to delete context
#     - **Answer:** A) A way to consume context in class components
#
# 25. **Can the Context API replace Redux for state management?**
#     - A) Yes, for simpler use cases
#     - B) No, Redux is more powerful
#     - C) Yes, for all use cases
#     - D) No, they serve different purposes
#     - **Answer:** A) Yes, for simpler use cases
#
# 26. **How do you initialize context with dynamic default values?**
#     - A) Use `useState` or `useReducer` in the `Provider`
#     - B) Use `useEffect` in the `Provider`
#     - C) Use a callback function in `createContext`
#     - D) Use `useContext` in the `Provider`
#     - **Answer:** A) Use useState or useReducer in the Provider
#
# 27. **What is the best practice for structuring context providers in a large application?**
#     - A) Group related state into separate context providers
#     - B) Use a single context provider for the entire app
#     - C) Avoid using
#
#  context providers
#     - D) Use context providers only in components
#     - **Answer:** A) Group related state into separate context providers
#
# 28. **What is the role of the `useReducer` hook in the Context API?**
#     - A) To manage complex state logic
#     - B) To manage simple state
#     - C) To handle HTTP requests
#     - D) To manage styles
#     - **Answer:** A) To manage complex state logic
#
# 29. **How do you provide context values to a deeply nested component?**
#     - A) Wrap the component tree with the `Provider`
#     - B) Pass context as props
#     - C) Use local storage
#     - D) Use `useEffect`
#     - **Answer:** A) Wrap the component tree with the Provider
#
# 30. **What is a potential pitfall of using the Context API?**
#     - A) Unintended re-renders due to value changes
#     - B) Too much boilerplate code
#     - C) Poor performance
#     - D) Complex setup
#     - **Answer:** A) Unintended re-renders due to value changes
#
# 31. **Can the Context API be used in conjunction with other state management libraries?**
#     - A) Yes, it can complement other libraries
#     - B) No, it replaces other libraries
#     - C) Only with Redux
#     - D) Only with MobX
#     - **Answer:** A) Yes, it can complement other libraries
#
# 32. **How do you memoize context values to prevent re-renders?**
#     - A) Use the `useMemo` hook
#     - B) Use the `useEffect` hook
#     - C) Use the `useState` hook
#     - D) Use the `useReducer` hook
#     - **Answer:** A) Use the useMemo hook
#
# 33. **How do you debug context value updates?**
#     - A) Use React DevTools
#     - B) Use `console.log`
#     - C) Use a debugger statement
#     - D) Use `alert`
#     - **Answer:** A) Use React DevTools
#
# 34. **What is the primary use case for the Context API?**
#     - A) Managing global state
#     - B) Handling component lifecycle
#     - C) Managing CSS
#     - D) Making HTTP requests
#     - **Answer:** A) Managing global state
#
# 35. **Can the Context API be used for theming?**
#     - A) Yes, it is a common use case
#     - B) No, it is only for state management
#     - C) Only with styled-components
#     - D) Only with CSS Modules
#     - **Answer:** A) Yes, it is a common use case
#
# 36. **How do you handle context updates that require asynchronous logic?**
#     - A) Use a custom hook with `useState` or `useReducer`
#     - B) Use `useEffect`
#     - C) Use `setTimeout`
#     - D) Use `Promise`
#     - **Answer:** A) Use a custom hook with useState or useReducer
#
# 37. **How do you handle context updates that depend on the previous state?**
#     - A) Use a function updater in `useState` or `useReducer`
#     - B) Use a class method
#     - C) Use `useEffect`
#     - D) Use `setTimeout`
#     - **Answer:** A) Use a function updater in useState or useReducer
#
# 38. **What is the `displayName` property used for in the Context API?**
#     - A) To label the context for debugging purposes
#     - B) To set the default context value
#     - C) To define the context type
#     - D) To provide context values
#     - **Answer:** A) To label the context for debugging purposes
#
# 39. **How can you provide different context values to different parts of the component tree?**
#     - A) Use multiple `Provider` components with different values
#     - B) Use a single `Provider`
#     - C) Use `useEffect`
#     - D) Use `useReducer`
#     - **Answer:** A) Use multiple Provider components with different values
#
# 40. **Can you pass functions as context values?**
#     - A) Yes, functions can be passed as context values
#     - B) No, only primitive values can be passed
#     - C) Only objects can be passed
#     - D) Only arrays can be passed
#     - **Answer:** A) Yes, functions can be passed as context values
#
# 41. **What is the key difference between `useContext` and `Context.Consumer`?**
#     - A) `useContext` is a hook, `Context.Consumer` is a component
#     - B) `useContext` is a component, `Context.Consumer` is a hook
#     - C) `useContext` is for class components, `Context.Consumer` is for functional components
#     - D) `useContext` can be used in both class and functional components
#     - **Answer:** A) useContext is a hook, Context.Consumer is a component
#
# 42. **How do you create a new context provider with default values?**
#     - A) Use `React.createContext(defaultValue)`
#     - B) Use `React.initializeContext(defaultValue)`
#     - C) Use `React.useContext(defaultValue)`
#     - D) Use `React.useState(defaultValue)`
#     - **Answer:** A) Use React.createContext(defaultValue)
#
# 43. **What is the best practice for updating context values in a large application?**
#     - A) Use a single context provider and manage updates centrally
#     - B) Use multiple context providers to manage different parts of the state
#     - C) Avoid using context for updates
#     - D) Use context only for static values
#     - **Answer:** B) Use multiple context providers to manage different parts of the state
#
# 44. **How can you test context providers and consumers in isolation?**
#     - A) Mock the context provider
#     - B) Use `useContext`
#     - C) Use `useState`
#     - D) Use `useEffect`
#     - **Answer:** A) Mock the context provider
#
# 45. **What is a common use case for combining the Context API with the `useReducer` hook?**
#     - A) To manage complex state and logic in a scalable way
#     - B) To handle HTTP requests
#     - C) To manage CSS
#     - D) To handle component lifecycle
#     - **Answer:** A) To manage complex state and logic in a scalable way
#
# 46. **How do you handle conditional context value updates?**
#     - A) Use a combination of `useState` and `useEffect`
#     - B) Use `useContext`
#     - C) Use `useMemo`
#     - D) Use `useRef`
#     - **Answer:** A) Use a combination of useState and useEffect
#
# 47. **How do you pass multiple context values to a single component?**
#     - A) Use multiple `useContext` hooks
#     - B) Use a single `useContext` hook
#     - C) Use a combined context
#     - D) Use props instead of context
#     - **Answer:** A) Use multiple useContext hooks
#
# 48. **What is the benefit of using the Context API for managing user authentication state?**
#     - A) It provides a global state that can be accessed from any component
#     - B) It improves performance
#     - C) It simplifies CSS management
#     - D) It handles HTTP requests
#     - **Answer:** A) It provides a global state that can be accessed from any component
#
# 49. **How do you handle context value updates that need to trigger side effects?**
#     - A) Use `useEffect` inside the context provider
#     - B) Use `useState`
#     - C) Use `useContext`
#     - D) Use `useMemo`
#     - **Answer:** A) Use useEffect inside the context provider
#
# 50. **How do you ensure context values are updated only when necessary?**
#     - A) Memoize context values using `useMemo`
#     - B) Use `useState`
#     - C) Use `useReducer`
#     - D) Use `useEffect`
#     - **Answer:** A) Memoize context values using useMemo

# %% [markdown]
# ### MongoDB and Mongoose MCQs with Answers
#
# 1. **Which of the following is true about MongoDB?**
#    - A) It is a NoSQL database
#    - B) It uses tables and rows
#    - C) It requires a schema
#    - D) It is based on SQL
#    - **Answer:** A) It is a NoSQL database
#
# 2. **What command is used to insert a document into a MongoDB collection?**
#    - A) `db.collection.insertOne(document)`
#    - B) `db.collection.add(document)`
#    - C) `db.collection.save(document)`
#    - D) `db.collection.insert(document)`
#    - **Answer:** A) db.collection.insertOne(document)
#
# 3. **How do you find all documents in a MongoDB collection?**
#    - A) `db.collection.findAll()`
#    - B) `db.collection.query()`
#    - C) `db.collection.getAll()`
#    - D) `db.collection.find({})`
#    - **Answer:** D) db.collection.find({})
#
# 4. **What query should be run to find documents where the `age` field is greater than 25?**
#    - A) `db.collection.find({ age: { $gt: 25 } })`
#    - B) `db.collection.query({ age: { $greater: 25 } })`
#    - C) `db.collection.search({ age: { $gt: 25 } })`
#    - D) `db.collection.select({ age: { $gt: 25 } })`
#    - **Answer:** A) db.collection.find({ age: { $gt: 25 } })
#
# 5. **What operator is used in MongoDB to match values within an array?**
#    - A) `$in`
#    - B) `$match`
#    - C) `$eq`
#    - D) `$arr`
#    - **Answer:** A) $in
#
# 6. **Which command is used to update a single document in MongoDB?**
#    - A) `db.collection.updateOne(filter, update)`
#    - B) `db.collection.update(filter, update)`
#    - C) `db.collection.modifyOne(filter, update)`
#    - D) `db.collection.modify(filter, update)`
#    - **Answer:** A) db.collection.updateOne(filter, update)
#
# 7. **What query would you use to update the `name` field to "John" for all documents where the `age` field is less than 30?**
#    - A) `db.collection.updateMany({ age: { $lt: 30 } }, { $set: { name: "John" } })`
#    - B) `db.collection.updateAll({ age: { $lt: 30 } }, { name: "John" })`
#    - C) `db.collection.modifyMany({ age: { $lt: 30 } }, { name: "John" })`
#    - D) `db.collection.modifyAll({ age: { $lt: 30 } }, { $set: { name: "John" } })`
#    - **Answer:** A) db.collection.updateMany({ age: { $lt: 30 } }, { $set: { name: "John" } })
#
# 8. **In Mongoose, how do you define a schema for a MongoDB collection?**
#    - A) `new mongoose.Schema(definition)`
#    - B) `new mongoose.Model(definition)`
#    - C) `new mongoose.Collection(definition)`
#    - D) `new mongoose.SchemaType(definition)`
#    - **Answer:** A) new mongoose.Schema(definition)
#
# 9. **Which method in Mongoose is used to save a new document to the database?**
#    - A) `model.save()`
#    - B) `model.insert()`
#    - C) `model.add()`
#    - D) `model.store()`
#    - **Answer:** A) model.save()
#
# 10. **How do you find a document by its `_id` in Mongoose?**
#     - A) `Model.findById(id)`
#     - B) `Model.find(id)`
#     - C) `Model.getById(id)`
#     - D) `Model.searchById(id)`
#     - **Answer:** A) Model.findById(id)
#
# 11. **What does the `$set` operator do in a MongoDB update query?**
#     - A) Replaces the value of a field
#     - B) Adds a new field
#     - C) Removes a field
#     - D) Increments the value of a field
#     - **Answer:** A) Replaces the value of a field
#
# 12. **Which of the following is used to delete a document in MongoDB?**
#     - A) `db.collection.deleteOne(filter)`
#     - B) `db.collection.remove(filter)`
#     - C) `db.collection.erase(filter)`
#     - D) `db.collection.delete(filter)`
#     - **Answer:** A) db.collection.deleteOne(filter)
#
# 13. **How do you connect to a MongoDB database using Mongoose?**
#     - A) `mongoose.connect(uri, options)`
#     - B) `mongoose.start(uri, options)`
#     - C) `mongoose.init(uri, options)`
#     - D) `mongoose.open(uri, options)`
#     - **Answer:** A) mongoose.connect(uri, options)
#
# 14. **What is the purpose of the `lean` method in Mongoose?**
#     - A) To return plain JavaScript objects instead of Mongoose documents
#     - B) To increase query performance
#     - C) To enforce schema validation
#     - D) To run aggregations
#     - **Answer:** A) To return plain JavaScript objects instead of Mongoose documents
#
# 15. **What does the `populate` method in Mongoose do?**
#     - A) Fills referenced paths with document data
#     - B) Adds fields to a document
#     - C) Removes fields from a document
#     - D) Validates schema definitions
#     - **Answer:** A) Fills referenced paths with document data
#
# 16. **Which query would you use to find documents where the `status` field is either "active" or "pending"?**
#     - A) `db.collection.find({ status: { $in: ["active", "pending"] } })`
#     - B) `db.collection.find({ status: { $or: ["active", "pending"] } })`
#     - C) `db.collection.query({ status: { $in: ["active", "pending"] } })`
#     - D) `db.collection.search({ status: { $or: ["active", "pending"] } })`
#     - **Answer:** A) db.collection.find({ status: { $in: ["active", "pending"] } })
#
# 17. **In Mongoose, what method would you use to find all documents that match a certain condition?**
#     - A) `Model.find(condition)`
#     - B) `Model.search(condition)`
#     - C) `Model.query(condition)`
#     - D) `Model.get(condition)`
#     - **Answer:** A) Model.find(condition)
#
# 18. **What is the command to find documents that do not have a `status` field set to "completed"?**
#     - A) `db.collection.find({ status: { $ne: "completed" } })`
#     - B) `db.collection.find({ status: { $not: "completed" } })`
#     - C) `db.collection.find({ status: { $neq: "completed" } })`
#     - D) `db.collection.find({ status: { $nq: "completed" } })`
#     - **Answer:** A) db.collection.find({ status: { $ne: "completed" } })
#
# 19. **Which method is used in Mongoose to perform aggregations?**
#     - A) `Model.aggregate(pipeline)`
#     - B) `Model.query(pipeline)`
#     - C) `Model.run(pipeline)`
#     - D) `Model.execute(pipeline)`
#     - **Answer:** A) Model.aggregate(pipeline)
#
# 20. **What is the correct syntax to create an index on the `name` field in MongoDB?**
#     - A) `db.collection.createIndex({ name: 1 })`
#     - B) `db.collection.ensureIndex({ name: 1 })`
#     - C) `db.collection.addIndex({ name: 1 })`
#     - D) `db.collection.index({ name: 1 })`
#     - **Answer:** A) db.collection.createIndex({ name: 1 })
#
# 21. **How do you remove a field from a document in MongoDB?**
#     - A) `$unset`
#     - B) `$remove`
#     - C) `$delete`
#     - D) `$drop`
#     - **Answer:** A) $unset
#
# 22. **In Mongoose, how do you add a new field to all documents in a collection?**
#     - A) `Model.updateMany({}, { $set: { newField: value } })`
#     - B) `Model.modifyMany({}, { newField: value })`
#     - C) `Model.saveMany({}, { newField: value })`
#     - D) `Model.insertMany({}, { newField: value })`
#     - **Answer:** A) Model.updateMany({}, { $set: { newField: value } })
#
# 23. **Which query would you use to find documents where the `tags` array contains "important"?**
#     - A) `db.collection.find({ tags: "important" })`
#     - B) `db.collection.find({ tags: { $elemMatch: "important" } })`
#     - C) `db.collection.find({ tags: { $in: ["important"] } })`
#     - D) `db.collection.find({ tags
#
# : { $contains: "important" } })`
#     - **Answer:** C) db.collection.find({ tags: { $in: ["important"] } })
#
# 24. **What is the purpose of the `timestamps` option in a Mongoose schema?**
#     - A) Automatically manage `createdAt` and `updatedAt` fields
#     - B) Log queries
#     - C) Set default values for date fields
#     - D) Validate date fields
#     - **Answer:** A) Automatically manage createdAt and updatedAt fields
#
# 25. **How do you ensure a field is unique in a Mongoose schema?**
#     - A) Set the `unique` property to `true` in the schema definition
#     - B) Set the `index` property to `true` in the schema definition
#     - C) Use the `ensureUnique` method
#     - D) Use the `uniqueIndex` method
#     - **Answer:** A) Set the unique property to true in the schema definition
#
# 26. **How do you find the first document in a MongoDB collection?**
#     - A) `db.collection.findOne()`
#     - B) `db.collection.first()`
#     - C) `db.collection.getFirst()`
#     - D) `db.collection.getOne()`
#     - **Answer:** A) db.collection.findOne()
#
# 27. **What method is used to update a document if it exists or insert it if it does not?**
#     - A) `updateOne` with `upsert: true`
#     - B) `modifyOne` with `upsert: true`
#     - C) `updateOrInsert`
#     - D) `saveOrUpdate`
#     - **Answer:** A) updateOne with upsert: true
#
# 28. **In Mongoose, how do you find all documents and sort them by a field in ascending order?**
#     - A) `Model.find().sort({ field: 1 })`
#     - B) `Model.find().order({ field: 1 })`
#     - C) `Model.query().sort({ field: 1 })`
#     - D) `Model.get().order({ field: 1 })`
#     - **Answer:** A) Model.find().sort({ field: 1 })
#
# 29. **What is the command to drop a MongoDB collection?**
#     - A) `db.collection.drop()`
#     - B) `db.collection.delete()`
#     - C) `db.collection.remove()`
#     - D) `db.collection.clear()`
#     - **Answer:** A) db.collection.drop()
#
# 30. **How do you create a new document in Mongoose?**
#     - A) `new Model(document).save()`
#     - B) `Model.insert(document)`
#     - C) `Model.add(document)`
#     - D) `Model.new(document)`
#     - **Answer:** A) new Model(document).save()
#
# 31. **Which method is used to find documents with a field not equal to a certain value?**
#     - A) `$ne`
#     - B) `$not`
#     - C) `$neq`
#     - D) `$exclude`
#     - **Answer:** A) $ne
#
# 32. **How do you ensure a field is indexed in a Mongoose schema?**
#     - A) Set the `index` property to `true` in the schema definition
#     - B) Set the `indexed` property to `true` in the schema definition
#     - C) Use the `ensureIndex` method
#     - D) Use the `indexField` method
#     - **Answer:** A) Set the index property to true in the schema definition
#
# 33. **What does the `collection.drop()` method do in MongoDB?**
#     - A) Deletes the entire collection and its documents
#     - B) Deletes all documents in the collection
#     - C) Deletes the collection indexes
#     - D) Deletes the collection schema
#     - **Answer:** A) Deletes the entire collection and its documents
#
# 34. **In Mongoose, how do you populate referenced documents in a query result?**
#     - A) `Model.find().populate(path)`
#     - B) `Model.query().populate(path)`
#     - C) `Model.get().populate(path)`
#     - D) `Model.search().populate(path)`
#     - **Answer:** A) Model.find().populate(path)
#
# 35. **What is the command to create a capped collection in MongoDB?**
#     - A) `db.createCollection(name, { capped: true, size: maxBytes })`
#     - B) `db.createCappedCollection(name, { size: maxBytes })`
#     - C) `db.newCollection(name, { capped: true, size: maxBytes })`
#     - D) `db.initCappedCollection(name, { size: maxBytes })`
#     - **Answer:** A) db.createCollection(name, { capped: true, size: maxBytes })
#
# 36. **Which method is used to count documents in a MongoDB collection?**
#     - A) `db.collection.countDocuments(query)`
#     - B) `db.collection.count(query)`
#     - C) `db.collection.documentCount(query)`
#     - D) `db.collection.getCount(query)`
#     - **Answer:** A) db.collection.countDocuments(query)
#
# 37. **How do you validate schema fields in Mongoose?**
#     - A) Use the `validate` property in the schema definition
#     - B) Use the `check` property in the schema definition
#     - C) Use the `verify` property in the schema definition
#     - D) Use the `ensure` property in the schema definition
#     - **Answer:** A) Use the validate property in the schema definition
#
# 38. **What is the use of the `autoIndex` option in Mongoose schemas?**
#     - A) Automatically create indexes defined in the schema
#     - B) Automatically create unique fields
#     - C) Automatically update indexes
#     - D) Automatically delete indexes
#     - **Answer:** A) Automatically create indexes defined in the schema
#
# 39. **Which MongoDB method is used to create a new user?**
#     - A) `db.createUser(userObject)`
#     - B) `db.addUser(userObject)`
#     - C) `db.newUser(userObject)`
#     - D) `db.user(userObject)`
#     - **Answer:** A) db.createUser(userObject)
#
# 40. **In Mongoose, how do you update multiple documents?**
#     - A) `Model.updateMany(filter, update)`
#     - B) `Model.modifyMany(filter, update)`
#     - C) `Model.updateAll(filter, update)`
#     - D) `Model.saveMany(filter, update)`
#     - **Answer:** A) Model.updateMany(filter, update)
#
# 41. **What does the `$inc` operator do in a MongoDB update query?**
#     - A) Increments the value of a field by a specified amount
#     - B) Decreases the value of a field by a specified amount
#     - C) Sets the value of a field to a specified amount
#     - D) Multiplies the value of a field by a specified amount
#     - **Answer:** A) Increments the value of a field by a specified amount
#
# 42. **How do you specify a required field in a Mongoose schema?**
#     - A) Set the `required` property to `true` in the schema definition
#     - B) Set the `mandatory` property to `true` in the schema definition
#     - C) Use the `ensure` property
#     - D) Use the `validate` property
#     - **Answer:** A) Set the required property to true in the schema definition
#
# 43. **What command is used to start the MongoDB server?**
#     - A) `mongod`
#     - B) `mongo`
#     - C) `mongodb`
#     - D) `mongos`
#     - **Answer:** A) mongod
#
# 44. **How do you ensure a field is unique in a MongoDB collection?**
#     - A) Create a unique index on the field
#     - B) Use the `ensureUnique` method
#     - C) Use the `uniqueField` property
#     - D) Use the `setUnique` method
#     - **Answer:** A) Create a unique index on the field
#
# 45. **In Mongoose, how do you apply a default value to a schema field?**
#     - A) Use the `default` property in the schema definition
#     - B) Use the `setDefault` property in the schema definition
#     - C) Use the `defaultValue` property in the schema definition
#     - D) Use the `ensureDefault` property in the schema definition
#     - **Answer:** A) Use the default property in the schema definition
#
# 46. **What is the role of the `ref` property in a Mongoose schema?**
#     - A) To reference another document in a different collection
#     - B) To reference a schema field
#     - C) To define a schema index
#     - D) To validate a schema field
#     - **Answer:** A) To reference another document in a different collection
#
# 47. **How do you specify a maximum value for a number field in a Mongoose schema?**
#     - A) Use the `max` property in the schema definition
#     - B) Use the `maximum` property in the schema definition
#     - C) Use the `limit` property in the schema definition
#     - D) Use the `top` property in the schema definition
#     - **Answer:** A) Use the max property in the schema definition
#
# 48. **Which MongoDB method is used to list all databases?**
#     - A) `show dbs`
#
#
#  - B) `list dbs`
#     - C) `get dbs`
#     - D) `display dbs`
#     - **Answer:** A) show dbs
#
# 49. **In Mongoose, how do you find documents that contain a specific substring in a field?**
#     - A) Use the `$regex` operator in the query
#     - B) Use the `$like` operator in the query
#     - C) Use the `$match` operator in the query
#     - D) Use the `$contains` operator in the query
#     - **Answer:** A) Use the $regex operator in the query
#
# 50. **How do you delete multiple documents in MongoDB?**
#     - A) `db.collection.deleteMany(filter)`
#     - B) `db.collection.removeMany(filter)`
#     - C) `db.collection.deleteAll(filter)`
#     - D) `db.collection.eraseMany(filter)`
#     - **Answer:** A) db.collection.deleteMany(filter)
